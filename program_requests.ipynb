# %%
import requests
import json
from datetime import datetime, timedelta

# timestamp = 1703019206145 / 1000  # Assuming the timestamp is in milliseconds, divide by 1000 to convert to seconds

# # Convert the timestamp to a datetime object
# dt_object = datetime.utcfromtimestamp(timestamp)

# # Format the datetime object as a string
# formatted_datetime = dt_object.strftime('%Y-%m-%d %H:%M:%S UTC')

# print("Converted DateTime:", formatted_datetime)


url = "https://store.transitstat.us/passio_go/rutgers"  # Replace this with the actual URL of the website

# Make an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data from the response
    data = response.json()

    # You can iterate through the data to access other information as needed
    for train_id, train_info in data["trains"].items():
        print(f"Bus {train_id}, {train_info['line']}: Destination - {train_info['dest']}")
        for prediction in train_info["predictions"]:
            timestamp = prediction["actualETA"] / 1000
            dt_object = datetime.utcfromtimestamp(timestamp)
            est_offset = -5  # EST is UTC-5
            est_timedelta = timedelta(hours=est_offset)
            dt_est = dt_object + est_timedelta
            
            formatted_datetime = dt_est.strftime('%H:%M:%S')
            print(f"Station {prediction['stationName']}: ETA - {formatted_datetime}")
        print()
else:
    print(f"Error: Unable to retrieve data. Status code: {response.status_code}")
# Out:
# Bus 1007, Route LX: Destination - Livingston Student Center
# Station College Avenue Student Center: ETA - 16:22:25
# Station The Yard: ETA - 16:22:25
# Station Student Activities Center NB: ETA - 16:23:25
# Station Livingston Plaza: ETA - 16:28:16
# Station Livingston Student Center: ETA - 16:30:25
# Station Quads: ETA - 16:32:25
#
# Bus 3278, Campus Connect: Destination - Hospital Campus
# Station NJIT: ETA - 16:23:13
# Station ICPH: ETA - 16:24:22
# Station Bergen Building: ETA - 16:27:56
# Station Medical School: ETA - 16:30:23
# Station ECC: ETA - 16:33:36
# Station CLJ: ETA - 16:36:19
# Station Washington Park: ETA - 16:36:33
# Station Broad St: ETA - 16:39:21
# Station University North: ETA - 16:39:47
# Station Physical Plant: ETA - 16:40:13
# Station Boyden Hall: ETA - 16:42:25
#
# Bus 4032, REXL Route: Destination - Red Oak Lane
#
# Bus 4034, Route REXB: Destination - Red Oak Lane
# Station Hill Center (NB): ETA - 16:28:54
# Station Allison Road Classrooms: ETA - 16:29:52
# Station Hill Center (SB): ETA - 16:31:22
#
# Bus 4035, Route H: Destination - Busch Student Center
# Station Werblin Recreation Center: ETA - 16:27:41
# Station Allison Road Classrooms: ETA - 16:32:25
# Station Hill Center (SB): ETA - 16:34:25
# Station Stadium West Lot: ETA - 16:36:25
# Station The Yard: ETA - 16:41:25
# Station Student Activities Center NB: ETA - 16:43:25
#
# Bus 4036, Route C: Destination - Stadium West Lot
#
# Bus 4039, Route B: Destination - Livingston Student Center
# Station Science Building: ETA - 16:22:25
# Station Busch Student Center: ETA - 16:24:25
#
# Bus 4040, Route LX: Destination - Livingston Student Center
# Station Student Activities Center NB: ETA - 16:22:31
# Station College Avenue Student Center: ETA - 16:23:25
# Station Livingston Plaza: ETA - 16:28:27
#
# Bus 4041, Route A: Destination - College Avenue Student Center
# Station Stadium West Lot: ETA - 16:23:20
# Station Hill Center (NB): ETA - 16:25:44
# Station Science Building: ETA - 16:26:51
# Station Busch Student Center: ETA - 16:29:00
# Station Werblin Main Entrance: ETA - 16:33:05
#
# Bus 4052, Route A: Destination - College Avenue Student Center
# Station Stadium West Lot: ETA - 16:26:17
# Station Hill Center (NB): ETA - 16:28:18
# Station Science Building: ETA - 16:29:13
# Station Busch Student Center: ETA - 16:30:49
# Station Werblin Main Entrance: ETA - 16:33:58
#
# Bus 4125, Penn Station Local: Destination - Newark Penn
# Station Blumenthal Hall: ETA - 16:22:46
# Station Penn Station: ETA - 16:28:25
# Station Bergen Bldg (back): ETA - 16:42:25
# Station Dental School: ETA - 16:44:25
# Station 180 W Market St: ETA - 16:45:25
#
# Bus 4128, Route F: Destination - Red Oak Lane
# Station Red Oak Lane: ETA - 16:22:35
# Station Lipman Hall: ETA - 16:30:51
# Station College Hall: ETA - 16:33:19
# Station Student Activities Center NB: ETA - 16:37:23
#
# Bus 4130, Penn Station Express: Destination - Hospital Campus
# Station Penn Station: ETA - 16:26:44
# Station Medical School: ETA - 16:35:04
# Station Hospital: ETA - 16:37:59
#
# Bus 4132, Penn Station Local: Destination - Newark Penn
# Station Medical School: ETA - 16:26:51
# Station Hospital: ETA - 16:29:51
# Station Bergen Bldg (back): ETA - 16:32:00
# Station Dental School: ETA - 16:34:40
# Station 180 W Market St: ETA - 16:35:24
# Station ICPH: ETA - 16:37:43
# Station NJIT: ETA - 16:39:17
# Station Blumenthal Hall: ETA - 16:41:06
#
# Bus 4133, Penn Station Express: Destination - Newark Penn
# Station Medical School: ETA - 16:26:51
# Station Hospital: ETA - 16:29:11
# Station Penn Station: ETA - 16:37:25
#
# Bus 4176, Route LX: Destination - Livingston Student Center
#
# Bus 4180, Route LX: Destination - Livingston Student Center
#
# Bus 4184, Route H: Destination - Busch Student Center
# Station The Yard: ETA - 16:23:17
# Station Student Activities Center NB: ETA - 16:25:18
# Station Werblin Recreation Center: ETA - 16:31:27
#
# Bus 4185, Route B: Destination - Livingston Student Center
# Station Quads: ETA - 16:23:25
# Station Hill Center (NB): ETA - 16:29:07
# Station Science Building: ETA - 16:30:33
# Station Busch Student Center: ETA - 16:32:17
# Station Livingston Plaza: ETA - 16:37:29
#
# Bus 4188, REXL Route: Destination - Red Oak Lane
#
# Bus 4190, Route EE: Destination - College Avenue Student Center
# Station SoCam Apts (NB): ETA - 16:23:15
# Station Student Activities Center NB: ETA - 16:28:33
# Station SoCam Apts (SB): ETA - 16:37:25
# Station Biel Road: ETA - 16:43:25
# Station Henderson: ETA - 16:44:25
# Station Gibbons: ETA - 16:46:25
#
# Bus 4197, Route REXB: Destination - Red Oak Lane
# Station Lipman Hall: ETA - 16:23:25
# Station College Hall: ETA - 16:24:27
# Station Hill Center (NB): ETA - 16:33:42
# Station Allison Road Classrooms: ETA - 16:34:44
# Station Hill Center (SB): ETA - 16:36:30
#
# Bus 4198, REXL Route: Destination - Red Oak Lane
# Station Livingston Student Center: ETA - 16:22:25
# Station Red Oak Lane: ETA - 16:36:01
# Station Lipman Hall: ETA - 16:36:48
# Station College Hall: ETA - 16:38:11
#
# Bus 4200, Route A: Destination - College Avenue Student Center
# Station Hill Center (NB): ETA - 16:22:25
# Station Science Building: ETA - 16:22:40
# Station Busch Student Center: ETA - 16:24:30
# Station Werblin Main Entrance: ETA - 16:28:24
#
# Bus 4205, Route LX: Destination - Livingston Student Center
#
# Bus 4211, Route REXB: Destination - Red Oak Lane
# Station College Hall: ETA - 16:23:43
# Station Hill Center (NB): ETA - 16:32:43
# Station Allison Road Classrooms: ETA - 16:33:40
# Station Hill Center (SB): ETA - 16:35:13
#
# Bus 5586, Camden: Destination - Camden
# Station BSB: ETA - 16:23:33
# Station City Lot 15: ETA - 16:25:25
# Station City Lot 16: ETA - 16:26:25
